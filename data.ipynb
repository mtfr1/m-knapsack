# %%
import numpy as np
import pandas as pd
colnames=['n', 'm', 'tightness', 'time', 'best_sol', 'best_bound', 'gap'] 
df = pd.read_csv("results.csv", names=colnames, header=None)

# %%
df
# Out:
#       n   m  tightness         time  best_sol     best_bound       gap
# 0   100   5       0.25     1.236546   24381.0   24383.437131  0.009996
# 1   100   5       0.50     0.182008   42757.0   42761.149259  0.009704
# 2   100   5       0.75     0.195698   59822.0   59827.900278  0.009863
# 3   250   5       0.25     9.111461   59312.0   59317.929668  0.009997
# 4   250   5       0.50    22.865517  109109.0  109119.910697  0.010000
# 5   250   5       0.75    20.161257  154668.0  154683.466359  0.010000
# 6   500   5       0.25  1845.249900  120148.0  120181.305461  0.027720
# 7   500   5       0.50   123.163114  218428.0  218449.842782  0.010000
# 8   500   5       0.75     8.482347  295828.0  295857.581355  0.010000
# 9   100  10       0.25    33.573587   23064.0   23066.305571  0.009996
# 10  100  10       0.50    11.873990   41395.0   41399.138751  0.009998
# 11  100  10       0.75     0.461613   57375.0   57380.676225  0.009893
# ...
